# %% [markdown]
# ### ЗАДАЧА: Откат подписок через стек
#
# Есть список команд для сервиса подписок: подключения, отключения, отчёты и `undo`.
# Нужно поддержать откат последнего успешного изменения,
# используя стек состояний.

# %%
subscriptions = {
    "Alice": {"music", "video"},
    "Bob": {"music"},
    "Dina": set(),
}

commands = [
    "add|Dina|books",
    "remove|Alice|video",
    "remove|Bob|cloud",
    "report",
    "undo",
    "add|Bob|cloud",
    "undo",
    "undo",
    "report",
]

history_stack = []
reports = []
errors = []
undo_count = 0
def get_snapshot (subs):
    return {user: service.copy() for user, service in subs.items()}

    

for command in commands:
    if command == "undo":
        # TODO 1: проверьте, что history_stack не пуст
        # TODO 2: если есть состояние, достаньте его через pop()
        # TODO 3: присвойте subscriptions извлечённое состояние
        # TODO 4: увеличьте undo_count на 1
        # TODO 5: если стек пуст, просто пропустите команду

        if history_stack:
            previous_state = history_stack.pop()
            subscriptions = previous_state
            undo_count += 1
        continue

    if command == "report":
        # TODO 6: сделайте независимую копию subscriptions
        #   подсказка: у каждого пользователя нужно копировать set отдельно
        # TODO 7: добавьте копию в reports
      
        reports.append(get_snapshot(subscriptions))
        continue

    action, user, service = command.split("|")
    current_services = subscriptions.get(user, set())

    if action == "add":
        # TODO 8: перед изменением сохраните снимок subscriptions в history_stack
        # TODO 9: если user отсутствует, создайте для него пустой set
        # TODO 10: добавьте service в subscriptions[user]
        print(get_snapshot(subscriptions))
        history_stack.append(get_snapshot(subscriptions))

        if user not in subscriptions:
            subscriptions[user] = set()
        subscriptions[user].add(service)


    elif action == "remove":
    
        # TODO 11: если service отсутствует у пользователя,
        #   добавьте текст ошибки в errors и не меняйте состояние
        # TODO 12: если service есть,
        #   сначала сохраните снимок subscriptions в history_stack,
        #   затем удалите service из subscriptions[user]
        if user not in subscriptions or service not in subscriptions [user]:
            errors.append(f"Cannot remove '{service}' from {user}: service not found")
        else:
           
            history_stack.append(get_snapshot(subscriptions))
            print(subscriptions[user])
            subscriptions[user].remove(service)

print("Отчёты:", reports)
print("Ошибки:", errors)
print("Успешных undo:", undo_count)
print("Финальные подписки:", subscriptions)
# Out:
# {'Alice': {'video', 'music'}, 'Bob': {'music'}, 'Dina': set()}
# {'video', 'music'}
# {'Alice': {'video', 'music'}, 'Bob': {'music'}, 'Dina': {'books'}}
# Отчёты: [{'Alice': {'music'}, 'Bob': {'music'}, 'Dina': {'books'}}, {'Alice': {'video', 'music'}, 'Bob': {'music'}, 'Dina': set()}]
# Ошибки: ["Cannot remove 'cloud' from Bob: service not found"]
# Успешных undo: 3
# Финальные подписки: {'Alice': {'video', 'music'}, 'Bob': {'music'}, 'Dina': set()}
